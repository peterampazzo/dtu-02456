# %%
labels = [1010010000,1000010000,1000000000,1011010000,1100010000]
accuracies = [0.7172855313700384,0.9053955964190661,0.0,0.0,0.0]
tots = [3905,8266,113,111,50]


zipped_lists = zip(accuracies,labels,tots)
sorted_pairs = sorted(zipped_lists)

triples = zip(*sorted_pairs)
accuracies,labels,tots = [list(tuple) for tuple in  triples]


labels2 = []
for lab in labels:
  lab_str = str(lab)
  labels2.append(encode[lab_str])

# %%
# do the plots 
import matplotlib.pyplot as plt

fig, ax = plt.subplots()  
# fig.figure(figsize=(15,7))
# creating the bar plot
ax.grid(zorder=0)
ax.barh(labels2, accuracies, color ='indianred',zorder=3)
ax.set_xlabel("Accuracy")
ax.set_title("Nepal finetuned: Within-class accuracies")
ax.set_yticks(range(0, len(labels2)), labels2)#, rotation='vertical'

# ax.text(labels2, accuracies, tots, ha = 'center')


for i, v in enumerate(tots):
    disp = int(accuracies[i]*tots[i])
    ax.text(1, i , str(disp)+ ' / ' + str(v), color='black')

fig.show()
fig.savefig("Nepal.png", dpi=1200, format="png",  bbox_inches="tight")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   # This is added back by InteractiveShellApp.init_path()

# %%
labels = [1000010000 ,
 1000000000 ,
 1010010100 ,
 1010000000 ,
 1010010000 ,
 1011010000 ,
 1011000000 ,
 1011100000 ,
 1110000000 ,
 1011010010 ,
 1110010000 ,
 1010000100,
 1100011000,
 1100000000 ,
 1110011100 ,
 1111010010 ,
 1110000100 ,
 1110010100 ,
 1111011000 ,
 1011010110 ,
 1111010000 ,
 1111010110 ,
 1111000000 ,
 1100010000 ,
 1011010100,
 1011110000 ,
 1011000010 ,
 1011000110]

accuracies = [0.930083949379777,0.8799231508165226,0.8632978221928915,0.7808061420345489,0.5119967466449776,0.24953789279112754,0.3426791277258567,
           0.0,0.14906832298136646 ,0.4143302180685358 ,0.16666666666666666 ,0.29874776386404295 ,0.0 ,0.0228310502283105, 0.0,0.06329113924050633,0.5454545454545454,
           0.4943820224719101,0.0,0.015625,0.02564102564102564,0.0,0.3076923076923077,0.24892703862660945,0.0,0.0,0.14285714285714285,0.0]
tots =[23943,8328,10607,5210,2459,541,1605,77,483,321,144, 559,130,219,149, 79,11,178,17,128,39,7,78,233,11,12,7,17]


zipped_lists = zip(accuracies,labels,tots)
sorted_pairs = sorted(zipped_lists)

triples = zip(*sorted_pairs)
accuracies,labels,tots = [list(tuple) for tuple in  triples]


labels2 = []
for lab in labels:
  lab_str = str(lab)
  labels2.append(encode[lab_str])

print(labels2)
encode = {'1000010000': 'DHelmet', '1000000000': 'DNoHelmet', '1100011000': 'DHelmetP0Helmet', '1100010000': 'DHelmetP0NoHelmet', '1100000000': 'DNoHelmetP0NoHelmet', '1010010100': 'DHelmetP1Helmet', '1010000100': 'DNoHelmetP1Helmet', '1010010000': 'DHelmetP1NoHelmet', '1010000000': 'DNoHelmetP1NoHelmet', '1110011100': 'DHelmetP0HelmetP1Helmet', '1110010100': 'DHelmetP0NoHelmetP1Helmet', '1110010000': 'DHelmetP0NoHelmetP1NoHelmet', '1110000100': 'DNoHelmetP0NoHelmetP1Helmet', '1110000000': 'DNoHelmetP0NoHelmetP1NoHelmet', '1110001000': 'DNoHelmetP0HelmetP1NoHelmet', '1011010110': 'DHelmetP1HelmetP2Helmet', '1011010010': 'DHelmetP1NoHelmetP2Helmet', '1011010100': 'DHelmetP1HelmetP2NoHelmet', '1011010000': 'DHelmetP1NoHelmetP2NoHelmet', '1011000110': 'DNoHelmetP1HelmetP2Helmet', '1011000010': 'DNoHelmetP1NoHelmetP2Helmet', '1011000000': 'DNoHelmetP1NoHelmetP2NoHelmet', '1111011110': 'DHelmetP0HelmetP1HelmetP2Helmet', '1111011010': 'DHelmetP0HelmetP1NoHelmetP2Helmet', '1111011000': 'DHelmetP0HelmetP1NoHelmetP2NoHelmet', '1111010110': 'DHelmetP0NoHelmetP1HelmetP2Helmet', '1111010010': 'DHelmetP0NoHelmetP1NoHelmetP2Helmet', '1111010000': 'DHelmetP0NoHelmetP1NoHelmetP2NoHelmet', '1111000000': 'DNoHelmetP0NoHelmetP1NoHelmetP2NoHelmet', '1111000010': 'DNoHelmetP0NoHelmetP1NoHelmetP2Helmet', '1011110000': 'DHelmetP1NoHelmetP2NoHelmetP3NoHelmet', '1011110001': 'DHelmetP1NoHelmetP2NoHelmetP3Helmet', '1011100000': 'DNoHelmetP1NoHelmetP2NoHelmetP3NoHelmet', '1111100000': 'DNoHelmetP0NoHelmetP1NoHelmetP2NoHelmetP3NoHelmet', '1111110001': 'DHelmetP0NoHelmetP1NoHelmetP2NoHelmetP3Helmet', '1111110000': 'DHelmetP0NoHelmetP1NoHelmetP2NoHelmetP3NoHelmet'}
# Out:
# ['DNoHelmetP1HelmetP2Helmet', 'DHelmetP1HelmetP2NoHelmet', 'DNoHelmetP1NoHelmetP2NoHelmetP3NoHelmet', 'DHelmetP1NoHelmetP2NoHelmetP3NoHelmet', 'DHelmetP0Helmet', 'DHelmetP0HelmetP1Helmet', 'DHelmetP0NoHelmetP1HelmetP2Helmet', 'DHelmetP0HelmetP1NoHelmetP2NoHelmet', 'DHelmetP1HelmetP2Helmet', 'DNoHelmetP0NoHelmet', 'DHelmetP0NoHelmetP1NoHelmetP2NoHelmet', 'DHelmetP0NoHelmetP1NoHelmetP2Helmet', 'DNoHelmetP1NoHelmetP2Helmet', 'DNoHelmetP0NoHelmetP1NoHelmet', 'DHelmetP0NoHelmetP1NoHelmet', 'DHelmetP0NoHelmet', 'DHelmetP1NoHelmetP2NoHelmet', 'DNoHelmetP1Helmet', 'DNoHelmetP0NoHelmetP1NoHelmetP2NoHelmet', 'DNoHelmetP1NoHelmetP2NoHelmet', 'DHelmetP1NoHelmetP2Helmet', 'DHelmetP0NoHelmetP1Helmet', 'DHelmetP1NoHelmet', 'DNoHelmetP0NoHelmetP1Helmet', 'DNoHelmetP1NoHelmet', 'DHelmetP1Helmet', 'DNoHelmet', 'DHelmet']

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,10))  
#fig.figure(figsize=(15,10))
# creating the bar plot
ax.grid(zorder=0)
ax.barh(labels2, accuracies, color ='indianred',zorder=3)
ax.set_xlabel("Accuracy")
ax.set_title("Myanmar: Within-class accuracies")
ax.set_yticks(range(0, len(labels2)), labels2)#, rotation='vertical'


for i, v in enumerate(tots):
    disp = int(accuracies[i]*tots[i])
    ax.text(1, i , str(disp)+ ' / ' + str(v), color='black')

fig.show()
fig.savefig("Myanmar.png", dpi=1200, format="png",  bbox_inches="tight")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   # Remove the CWD from sys.path while we load stuff.
